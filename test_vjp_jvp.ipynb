# %%
# %load_ext autoreload
# %autoreload 2

# %%
import jax
# jax.config.update("jax_enable_x64", True)

import jax.numpy as jnp
import jax.random as jr
from jax.tree_util import Partial

import hugegp as gp
import hugegp_cuda as hgc
import jaxkd as jk

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import time
from tqdm import tqdm

rng = jr.key(137)
# Out:
# 2025-08-24 13:13:24.190620: E external/xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/xla_bridge.py:943, in _init_backend(platform)
#     942 logger.debug("Initializing backend '%s'", platform)
# --> 943 backend = registration.factory()
#     944 # TODO(skye): consider raising more descriptive errors directly from backend
#     945 # factories instead of returning None.
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/xla_bridge.py:633, in register_plugin.<locals>.factory()
#     632 if distributed.global_state.client is None:
# --> 633   return xla_client.make_c_api_client(plugin_name, updated_options, None)
#     635 distribute_options = {
#     636     'node_id': distributed.global_state.process_id,
#     637     'num_nodes': distributed.global_state.num_processes,
#     638 }
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jaxlib/xla_client.py:159, in make_c_api_client(plugin_name, options, distributed_client)
#     158   options = {}
# --> 159 return _xla.get_c_api_client(plugin_name, options, distributed_client)
#
# XlaRuntimeError: FAILED_PRECONDITION: No visible GPU devices.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 18
#      15 import time
#      16 from tqdm import tqdm
# ---> 18 rng = jr.key(137)
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/random.py:220, in key(seed, impl)
#     202 def key(seed: int | ArrayLike, *,
#     203         impl: PRNGSpecDesc | None = None) -> Array:
#     204   """Create a pseudo-random number generator (PRNG) key given an integer seed.
#     205
#     206   The result is a scalar array containing a key, whose dtype indicates
#    (...)    218     and ``fold_in``.
#     219   """
# --> 220   return _key('key', seed, impl)
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/random.py:200, in _key(ctor_name, seed, impl_spec)
#     196 if np.ndim(seed):
#     197   raise TypeError(
#     198       f"{ctor_name} accepts a scalar seed, but was given an array of "
#     199       f"shape {np.shape(seed)} != (). Use jax.vmap for batching")
# --> 200 return prng.random_seed(seed, impl=impl)
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/prng.py:548, in random_seed(seeds, impl)
#     543 def random_seed(seeds: int | typing.ArrayLike, impl: PRNGImpl) -> PRNGKeyArray:
#     544   # Avoid overflow error in X32 mode by first converting ints to int64.
#     545   # This breaks JIT invariance for large ints, but supports the common
#     546   # use-case of instantiating with Python hashes in X32 mode.
#     547   if isinstance(seeds, int):
# --> 548     seeds_arr = jnp.asarray(np.int64(seeds))
#     549   else:
#     550     seeds_arr = jnp.asarray(seeds)
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/numpy/lax_numpy.py:5714, in asarray(a, dtype, order, copy, device)
#    5712 if dtype is not None:
#    5713   dtype = dtypes.canonicalize_dtype(dtype, allow_extended_dtype=True)  # type: ignore[assignment]
# -> 5714 return array(a, dtype=dtype, copy=bool(copy), order=order, device=device)
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/numpy/lax_numpy.py:5548, in array(object, dtype, copy, order, ndmin, device)
#    5546 else:
#    5547   raise TypeError(f"Unexpected input type for array: {type(object)}")
# -> 5548 out_array: Array = lax_internal._convert_element_type(
#    5549     out, dtype, weak_type=weak_type, sharding=sharding)
#    5550 if ndmin > np.ndim(out_array):
#    5551   out_array = lax.expand_dims(out_array, range(ndmin - np.ndim(out_array)))
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/lax/lax.py:1727, in _convert_element_type(operand, new_dtype, weak_type, sharding, warn_on_complex_to_real_cast)
#    1725   return operand
#    1726 else:
# -> 1727   return convert_element_type_p.bind(
#    1728       operand, new_dtype=new_dtype, weak_type=bool(weak_type),
#    1729       sharding=sharding)
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/core.py:496, in Primitive.bind(self, *args, **params)
#     494 def bind(self, *args, **params):
#     495   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 496   return self._true_bind(*args, **params)
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/core.py:512, in Primitive._true_bind(self, *args, **params)
#     510 trace_ctx.set_trace(eval_trace)
#     511 try:
# --> 512   return self.bind_with_trace(prev_trace, args, params)
#     513 finally:
#     514   trace_ctx.set_trace(prev_trace)
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/lax/lax.py:4875, in _convert_element_type_bind_with_trace(trace, args, params)
#    4873 def _convert_element_type_bind_with_trace(trace, args, params):
#    4874   sharding = params['sharding']
# -> 4875   operand = core.Primitive.bind_with_trace(convert_element_type_p, trace, args, params)
#    4876   if sharding is not None and sharding._is_concrete:
#    4877     with core.set_current_trace(trace):
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/core.py:517, in Primitive.bind_with_trace(self, trace, args, params)
#     516 def bind_with_trace(self, trace, args, params):
# --> 517   return trace.process_primitive(self, args, params)
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/core.py:1017, in EvalTrace.process_primitive(self, primitive, args, params)
#    1015 args = map(full_lower, args)
#    1016 check_eval_args(args)
# -> 1017 return primitive.impl(*args, **params)
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/dispatch.py:89, in apply_primitive(prim, *args, **params)
#      87 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      88 try:
# ---> 89   outs = fun(*args)
#      90 finally:
#      91   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 13 frame]
#
# File ~/hugegp/.venv/lib/python3.13/site-packages/jax/_src/xla_bridge.py:873, in backends()
#     871       else:
#     872         err_msg += " (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)"
# --> 873       raise RuntimeError(err_msg)
#     875 assert _default_backend is not None
#     876 if not config.jax_platforms.value:
#
# RuntimeError: Unable to initialize backend 'cuda': FAILED_PRECONDITION: No visible GPU devices. (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)
